# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["HF_API_TOKEN"] = os.getenv("HF_API_TOKEN")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")
os.environ["HUGGINGFACEHUB_API_TOKEN"] = os.getenv("HUGGINGFACEHUB_API_TOKEN")
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAI


llm = OpenAI(model_name = "gpt-4o")

print(llm)
# Out:
# OpenAI
# Params: {'model_name': 'gpt-4o', 'temperature': 0.7, 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0, 'n': 1, 'seed': None, 'logprobs': None, 'max_tokens': 256}

# %%
##Input and get response
llm.invoke("What is Langchain?")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 ##Input and get response
# ----> 2 llm.invoke("What is Langchain?")
#
# File ~/Langchain/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:390, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     379 @override
#     380 def invoke(
#     381     self,
#    (...)
#     386     **kwargs: Any,
#     387 ) -> str:
#     388     config = ensure_config(config)
#     389     return (
# --> 390         self.generate_prompt(
#     391             [self._convert_input(input)],
#     392             stop=stop,
#     393             callbacks=config.get("callbacks"),
#     394             tags=config.get("tags"),
#     395             metadata=config.get("metadata"),
#     396             run_name=config.get("run_name"),
#     397             run_id=config.pop("run_id", None),
#     398             **kwargs,
#     399         )
#     400         .generations[0][0]
#     401         .text
#     402     )
#
# File ~/Langchain/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:789, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     780 @override
#     781 def generate_prompt(
#     782     self,
#    (...)
#     786     **kwargs: Any,
#     787 ) -> LLMResult:
#     788     prompt_strings = [p.to_string() for p in prompts]
# --> 789     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Langchain/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:1000, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     985 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     986     run_managers = [
#     987         callback_manager.on_llm_start(
#     988             self._serialized,
#    (...)
#     998         )
#     999     ]
# -> 1000     return self._generate_helper(
#    1001         prompts,
#    1002         stop,
#    1003         run_managers,
#    1004         new_arg_supported=bool(new_arg_supported),
#    1005         **kwargs,
#    1006     )
#    1007 if len(missing_prompts) > 0:
#    1008     run_managers = [
#    1009         callback_managers[idx].on_llm_start(
#    1010             self._serialized,
#    (...)
#    1017         for idx in missing_prompt_idxs
#    1018     ]
#
# File ~/Langchain/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:815, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     804 def _generate_helper(
#     805     self,
#     806     prompts: list[str],
#    (...)
#     811     **kwargs: Any,
#     812 ) -> LLMResult:
#     813     try:
#     814         output = (
# --> 815             self._generate(
#     816                 prompts,
#     817                 stop=stop,
#     818                 # TODO: support multiple run managers
#     819                 run_manager=run_managers[0] if run_managers else None,
#     820                 **kwargs,
#     821             )
#     822             if new_arg_supported
#     823             else self._generate(prompts, stop=stop)
#     824         )
#     825     except BaseException as e:
#     826         for run_manager in run_managers:
#
# File ~/Langchain/venv/lib/python3.10/site-packages/langchain_openai/llms/base.py:446, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     430     choices.append(
#     431         {
#     432             "text": generation.text,
#    (...)
#     443         }
#     444     )
#     445 else:
# --> 446     response = self.client.create(prompt=_prompts, **params)
#     447     if not isinstance(response, dict):
#     448         # V1 client returns the response in an PyDantic object instead of
#     449         # dict. For the transition period, we deep convert it to dict.
#     450         response = response.model_dump()
#
# File ~/Langchain/venv/lib/python3.10/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Langchain/venv/lib/python3.10/site-packages/openai/resources/completions.py:541, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     512 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     513 def create(
#     514     self,
#    (...)
#     539     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     540 ) -> Completion | Stream[Completion]:
# --> 541     return self._post(
#     542         "/completions",
#     543         body=maybe_transform(
#     544             {
#     545                 "model": model,
#     546                 "prompt": prompt,
#     547                 "best_of": best_of,
#     548                 "echo": echo,
#     549                 "frequency_penalty": frequency_penalty,
#     550                 "logit_bias": logit_bias,
#     551                 "logprobs": logprobs,
#     552                 "max_tokens": max_tokens,
#     553                 "n": n,
#     554                 "presence_penalty": presence_penalty,
#     555                 "seed": seed,
#     556                 "stop": stop,
#     557                 "stream": stream,
#     558                 "stream_options": stream_options,
#     559                 "suffix": suffix,
#     560                 "temperature": temperature,
#     561                 "top_p": top_p,
#     562                 "user": user,
#     563             },
#     564             completion_create_params.CompletionCreateParamsStreaming
#     565             if stream
#     566             else completion_create_params.CompletionCreateParamsNonStreaming,
#     567         ),
#     568         options=make_request_options(
#     569             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     570         ),
#     571         cast_to=Completion,
#     572         stream=stream or False,
#     573         stream_cls=Stream[Completion],
#     574     )
#
# File ~/Langchain/venv/lib/python3.10/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Langchain/venv/lib/python3.10/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': "You didn't provide an API key. You need to provide your API key in an Authorization header using Bearer auth (i.e. Authorization: Bearer YOUR_KEY), or as the password field (with blank username) if you're accessing the API from your browser and are prompted for a username and password. You can obtain an API key from https://platform.openai.com/account/api-keys.", 'type': 'invalid_request_error', 'param': None, 'code': None}}

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an Expert AI Engineer. Provide me answers based on the questions."),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an Expert AI Engineer. Provide me answers based on the questions.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt|llm
response = chain.invoke({"input" : "What is Langchain?"})
print(response)

# %%
#string output parser

from lanngchain_core.output_parsers import StrOutputParser

string_parser = StrOutputParser()
chain = prompt|llm|string_parser

response = chain.invoke({"input" : "What is Langchain?"})
print(response)
